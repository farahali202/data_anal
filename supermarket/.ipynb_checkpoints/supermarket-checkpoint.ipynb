# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('supermarkt_salesnew.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
df['hour']=pd.to_datetime(df['Time'],format="%H:%M").dt.hour
df['Date']=pd.to_datetime(df['Date'])
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day
df
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer_type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating, hour, month, day]
# Index: []

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # wich city the sales are high/How does the sales revenue vary across different  cities (City)?

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
sns.countplot(x='City',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
revenue_by_City = df.groupby('City')['Total'].sum().reset_index()
plt.bar(revenue_by_City['City'], revenue_by_City['Total'])

plt.xlabel('City')
plt.ylabel('Total Revenue')
plt.title('Sales Revenue by City')

plt.show()

# %% [markdown]
# # which custom buy alot/What is the distribution of customers based on their membership type (Customer_type)?

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.countplot(x='Customer_type',data=df)
# Out:
# <AxesSubplot:xlabel='Customer_type', ylabel='count'>

# %%
sns.countplot(x="Customer_type", hue = "Branch", data =df)
plt.show()

# %%
revenue_by_custom = df.groupby('Customer_type')['Total'].sum().reset_index()
plt.bar(revenue_by_custom['Customer_type'], revenue_by_custom['Total'])

plt.xlabel('customer')
plt.ylabel('Total Revenue')
plt.title('Sales Revenue by custom')

plt.show()

# %% [markdown]
# # wicg gender bay more/What is the gender distribution of customers? Is there any gender preference for specific product lines?

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
revenue_by_gender = df.groupby('Gender')['Total'].sum().reset_index()

plt.bar(revenue_by_gender['Gender'], revenue_by_gender['Total'])

plt.xlabel('Gender')
plt.ylabel('Total Revenue')
plt.title('Sales Revenue by Gender')

plt.show()

# %% [markdown]
# # which product are bought more/Which product line generates the highest gross income? Are there any notable trends or patterns in product sales?

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Create a pie chart
plt.pie(df['Product line'].value_counts(), labels=df['Product line'].value_counts().index, autopct='%1.1f%%')

# Set title
plt.title('Distribution of Product')

# Display the plot
plt.show()

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %%
prod=df.groupby(by=['Product line']).sum()[['Quantity']].sort_values(by='Quantity')
cmap = 'viridis'
sns.barplot(x='Quantity',y=prod.index,data=prod,palette=cmap)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Product line'>

# %%
sns.boxenplot(y = 'Product line', x = 'Total', data=df )
plt.show()

# %%
sns.boxenplot(y = 'Product line', x = 'Rating', data=df )
plt.show()

# %%
sns.relplot(x="hour",  y = 'Quantity', col= 'Product line' , row= 'Branch', estimator = None, kind="line", data =df)
plt.show()

# %% [raw]
# From the above plots, we can see that food and beverages sales usually high in all three branches at evening especially around 19:00

# %% [markdown]
# # is a customer with method of pyment -->can increase total/Which payment method (Payment) is most commonly used by customers? Does it vary across different branches or cities?

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %%
sns.countplot(x='Payment',data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
revenue_by_payment = df.groupby('Payment')['Total'].sum().reset_index()
plt.bar(revenue_by_payment['Payment'], revenue_by_payment['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
sns.countplot(x="Payment", hue = "Branch", data =df)
plt.show()

# %% [markdown]
# # How does the unit price of products vary across different product lines? Are there any outliers or significant price differences?

# %%
cmap = 'viridis'
prod=df.groupby(by=['Product line']).sum()[['Unit price']].sort_values(by='Unit price')
sns.barplot(x='Unit price',y=prod.index,data=prod,estimator=np.median)
plt.show()

# %% [markdown]
# # How does the sales revenue vary across different branches (Branch) ?

# %%
import matplotlib.pyplot as plt
revenue_by_branch = df.groupby('Branch')['Rating'].sum().reset_index()
plt.bar(revenue_by_branch['Branch'], revenue_by_branch['Rating'])

plt.xlabel('Branch')
plt.ylabel('Total Rating')
plt.title('Sales Rating by Branch')

plt.xticks(rotation=45)

plt.show()

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %% [markdown]
# # What is the average rating given by customers (Rating)? Are there any correlations between the rating and other variables?

# %%
df.Rating.mean()
# Out:
# 6.972700000000003

# %%
correlation_matrix = df.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# hour                       0.008242 -0.007317 -0.002770 -0.002770 -0.002770
# month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
# day                        0.057021 -0.043347 -0.002515 -0.002515 -0.002515
#
# ...

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# CONCLUSION:
#
# 1-Unit price, Quantity, Tax 5%, Total, cogs, and gross income are highly positively correlated with each other. This indicates that these variables have a strong linear relationship and tend to increase or decrease together.
#
# 2-Rating has a weak negative correlation with Unit price, Quantity, Tax 5%, Total, cogs, gross income, and hour. This suggests that as the rating decreases, these variables may slightly decrease as well.
#
# 2-There is a weak positive correlation between hour and Unit price, indicating a slight tendency for the unit price to increase with the hour.
#
# 3-The variable "gross margin percentage" has missing values (NaN) and does not contribute to the correlation analysis.

# %% [markdown]
# # How does the sales volume (Quantity) vary over time (Date)? Are there any seasonal trends or patterns?

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %%
sns.relplot(x="hour",  y = 'Quantity', col= 'month' , row= 'Branch',
                           kind="line", style="Gender", data =df)
plt.show()

# %%
genderCount  = sns.lineplot(x="Date",  y = 'Quantity',data =df)
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.title('Sales Volume Variation over Date')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # What are the peak hours of sales (hour)? Does the sales volume vary based on the time of day?

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#    hour  month  day
# 0    13      1    5
# 1    10      3    8
# 2    13      3    3

# %%
genderCount  = sns.lineplot(x="hour",  y = 'Quantity',data =df).set_title("Product Sales per Hour")
plt.xlabel('Hour')
plt.ylabel('Sales Volume')
plt.title('Sales Volume Variation over hour')
plt.xticks(rotation=45)
plt.show()

# %%
sns.relplot(x="hour",  y = 'Total', col= 'month' , row= 'Branch', estimator = None, kind="line", data =df)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
sns.lmplot(x='Total',y='Quantity',hue='Gender',data=df,markers=['o','^'],
          scatter_kws={'s':100,'linewidth':0.5,'edgecolor':'w'})
